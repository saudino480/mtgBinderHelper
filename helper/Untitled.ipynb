# %%
import json
import pandas as pd

# %%
all_cards = json.load(open("../data/AllPrintings.json"))

# %%
url = "https://api.scryfall.com/" + "cards/collection"
sesh = Session()
sesh.headers.update({'Content-Type' : 'application/json'})

# %%
parameters = {
    'identifiers' : [{'name' : 'Nicol Bolas, God-Pharaoh (Foil Etched)',
                      'set' : '2X2'}]
}

# %%
all_cards['data']['2X2']
# Out:
# {'baseSetSize': 577,
#  'cards': [{'artist': 'Mark Tedin',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': [],
#    'colors': [],
#    'convertedManaCost': 15.0,
#    'finishes': ['nonfoil', 'foil'],
#    'foreignData': [],
#    'frameEffects': ['legendary'],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263561',
#     'cardKingdomId': '262998',
#     'mcmId': '664853',
#     'mcmMetaId': '11139',
#     'mtgjsonV4Id': 'c4b538a6-9c04-5fbc-9717-0cbdc066da88',
#     'mtgoId': '101486',
#     'multiverseId': '571334',
#     'scryfallId': '249db4d4-2542-47ee-a216-e13ffbc2319c',
#     'scryfallIllustrationId': '77d49e83-98fd-440e-a4ee-ecf8c5535899',
#     'scryfallOracleId': '900ca697-ad38-4b2b-bc74-2ff7eb6ea951',
#     'tcgplayerProductId': '276660'},
#    'isReprint': True,
#    'keywords': ['Annihilator', 'Flying', 'Protection'],
#    'language': 'English',
#    'layout': 'normal',
#    'leadershipSkills': {'brawl': False,
#     'commander': True,
#     'oathbreaker': False},
#    'legalities': {'commander': 'Banned',
#     'duel': 'Banned',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{15}',
#    'manaValue': 15.0,
#    'name': 'Emrakul, the Aeons Torn',
#    'number': '1',
#    'power': '15',
#    'printings': ['2X2',
#     'MM2',
#     'PLIST',
#     'PPRO',
#     'PRM',
#     'PROE',
#     'PUMA',
#     'ROE',
#     'UMA'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/e2a41945cd846c32',
#     'cardKingdomFoil': 'https://mtgjson.com/links/1c85fafd68da4d4c',
#     'cardmarket': 'https://mtgjson.com/links/c5732ec4bda3b396',
#     'tcgplayer': 'https://mtgjson.com/links/cf8c3aacbaf7cd51'},
#    'rarity': 'mythic',
#    'rulings': [{'date': '2010-06-15',
#      'text': 'Annihilator abilities trigger and resolve during the declare attackers step. The defending player chooses and sacrifices the required number of permanents before they declare blockers. Any creatures sacrificed this way won’t be able to block.'},
#     {'date': '2010-06-15',
#      'text': 'If a creature with annihilator is attacking a planeswalker, and the defending player chooses to sacrifice that planeswalker, the attacking creature continues to attack. It may be blocked. If it isn’t blocked, it simply won’t deal combat damage to anything.'},
#     {'date': '2018-12-07',
#      'text': 'Emrakul’s second ability triggers as you cast it, and that ability resolves before the spell itself. It resolves even if that spell is somehow removed from the stack.'},
#     {'date': '2018-12-07',
#      'text': 'Emrakul can be targeted by spells that try to counter it (such as Countersquall). Those spells will resolve, but the part of their effect that would counter Emrakul won’t do anything. Any other effects those spells have will work as normal.'},
#     {'date': '2018-12-07',
#      'text': '“Colored spells” is not synonymous with “colored cards.” For example, even though creatures are spells when they’re cast, they’re not spells when they’re on the battlefield and can block Emrakul; and triggered abilities of permanents entering the battlefield (such as that of Banishing Light) can target it.'},
#     {'date': '2018-12-07',
#      'text': 'Emrakul can’t be the target of colored Aura spells, but colored Auras can be put onto the battlefield enchanting it.'}],
#    'securityStamp': 'oval',
#    'setCode': '2X2',
#    'subtypes': ['Eldrazi'],
#    'supertypes': ['Legendary'],
#    'text': "This spell can't be countered.\nWhen you cast this spell, take an extra turn after this one.\nFlying, protection from spells that are one or more colors, annihilator 6\nWhen Emrakul, the Aeons Torn is put into a graveyard from anywhere, its owner shuffles their graveyard into their library.",
#    'toughness': '15',
#    'type': 'Legendary Creature — Eldrazi',
#    'types': ['Creature'],
#    'uuid': '5169592e-dd93-535a-b5af-51c9aaccbf36',
#    'variations': ['f58d9aa7-9a43-5556-ae17-9636e6c7ef15',
#     '1ec929f1-c791-5dfe-b3a3-1b29a165ea72',
#     'a9e37c90-1112-53ea-a442-27897a256f76']},
#   {'artist': 'Michael Komarck',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': [],
#    'colors': [],
#    'convertedManaCost': 10.0,
#    'edhrecRank': 877,
#    'finishes': ['nonfoil', 'foil'],
#    'foreignData': [],
#    'frameEffects': ['legendary'],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263426',
#     'cardKingdomId': '262646',
#     'mcmId': '663977',
#     'mcmMetaId': '11104',
#     'mtgjsonV4Id': '9fb977ee-bcbe-5c45-9031-88696ae34661',
#     'mtgoId': '101488',
#     'multiverseId': '571335',
#     'scryfallId': 'd27cf7b7-7982-46bd-a559-7789c0e74bae',
#     'scryfallIllustrationId': '8a8e7660-855a-4ebb-8942-6c56d178c88e',
#     'scryfallOracleId': '7b8528b0-71eb-4c9e-bed9-aa2d2e84038f',
#     'tcgplayerProductId': '276259'},
#    'isReprint': True,
#    'keywords': ['Annihilator'],
#    'language': 'English',
#    'layout': 'normal',
#    'leadershipSkills': {'brawl': False,
#     'commander': True,
#     'oathbreaker': False},
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{10}',
#    'manaValue': 10.0,
#    'name': 'Kozilek, Butcher of Truth',
#    'number': '2',
#    'power': '12',
#    'printings': ['2X2', 'MM2', 'PLIST', 'PUMA', 'ROE', 'UMA'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/320e53f896b4c734',
#     'cardKingdomFoil': 'https://mtgjson.com/links/cd7dcd012c42fef1',
#     'cardmarket': 'https://mtgjson.com/links/b15e6b8c1b31ce52',
#     'tcgplayer': 'https://mtgjson.com/links/5b8618b880c03353'},
#    'rarity': 'mythic',
#    'rulings': [{'date': '2010-06-15',
#      'text': 'Annihilator abilities trigger and resolve during the declare attackers step. The defending player chooses and sacrifices the required number of permanents before they declare blockers. Any creatures sacrificed this way won’t be able to block.'},
#     {'date': '2010-06-15',
#      'text': 'If a creature with annihilator is attacking a planeswalker, and the defending player chooses to sacrifice that planeswalker, the attacking creature continues to attack. It may be blocked. If it isn’t blocked, it simply won’t deal combat damage to anything.'},
#     {'date': '2018-12-07',
#      'text': 'Kozilek’s first ability triggers as you cast it, and that ability resolves before the spell itself. It resolves even if the spell is countered.'}],
#    'securityStamp': 'oval',
#    'setCode': '2X2',
#    'subtypes': ['Eldrazi'],
#    'supertypes': ['Legendary'],
#    'text': 'When you cast this spell, draw four cards.\nAnnihilator 4 (Whenever this creature attacks, defending player sacrifices four permanents.)\nWhen Kozilek, Butcher of Truth is put into a graveyard from anywhere, its owner shuffles their graveyard into their library.',
#    'toughness': '12',
#    'type': 'Legendary Creature — Eldrazi',
#    'types': ['Creature'],
#    'uuid': '14e24424-15a0-5b28-817f-de8c72748469',
#    'variations': ['c83d9fb9-922a-50cd-ac0b-59627916983d',
#     'bc7929be-9502-5450-92bf-f154bf326456',
#     '6d4e18c2-1652-5291-99db-e0c592132359']},
#   {'artist': 'Aleksi Briclot',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': [],
#    'colors': [],
#    'convertedManaCost': 11.0,
#    'edhrecRank': 934,
#    'finishes': ['nonfoil', 'foil'],
#    'foreignData': [],
#    'frameEffects': ['legendary'],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263482',
#     'cardKingdomId': '262798',
#     'mcmId': '664142',
#     'mcmMetaId': '11133',
#     'mtgjsonV4Id': '679d16ff-e2be-5dfb-ad2d-92b8636526e4',
#     'mtgoId': '101490',
#     'multiverseId': '571336',
#     'scryfallId': '9464a820-65de-44f2-9895-46a35e8621a0',
#     'scryfallIllustrationId': '7738c4ae-497f-49c1-b3d3-4801b0a66ab8',
#     'scryfallOracleId': 'b817bc56-9b4d-4c50-bafa-3c652b99578f',
#     'tcgplayerProductId': '276353'},
#    'isReprint': True,
#    'keywords': ['Annihilator', 'Indestructible'],
#    'language': 'English',
#    'layout': 'normal',
#    'leadershipSkills': {'brawl': False,
#     'commander': True,
#     'oathbreaker': False},
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{11}',
#    'manaValue': 11.0,
#    'name': 'Ulamog, the Infinite Gyre',
#    'number': '3',
#    'power': '10',
#    'printings': ['2X2', 'MM2', 'PUMA', 'ROE', 'UMA', 'V11'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/f15478cc2d85efda',
#     'cardKingdomFoil': 'https://mtgjson.com/links/712595fa6713b5c3',
#     'cardmarket': 'https://mtgjson.com/links/29f25476e7a9fb09',
#     'tcgplayer': 'https://mtgjson.com/links/1b7e310bcb6a9194'},
#    'rarity': 'mythic',
#    'rulings': [{'date': '2010-06-15',
#      'text': 'Annihilator abilities trigger and resolve during the declare attackers step. The defending player chooses and sacrifices the required number of permanents before they declare blockers. Any creatures sacrificed this way won’t be able to block.'},
#     {'date': '2010-06-15',
#      'text': 'If a creature with annihilator is attacking a planeswalker, and the defending player chooses to sacrifice that planeswalker, the attacking creature continues to attack. It may be blocked. If it isn’t blocked, it simply won’t deal combat damage to anything.'},
#     {'date': '2013-07-01',
#      'text': 'Lethal damage and effects that say “destroy” won’t cause a creature with indestructible to be put into the graveyard. However, a creature with indestructible can be put into the graveyard for a number of reasons. The most likely reasons are if it’s sacrificed, if it’s legendary and another legendary creature with the same name is controlled by the same player, or if its toughness is 0 or less.'},
#     {'date': '2018-12-07',
#      'text': 'Ulamog’s ability triggers as you cast it, and that ability resolves before the spell itself. It resolves even if that spell is countered.'}],
#    'securityStamp': 'oval',
#    'setCode': '2X2',
#    'subtypes': ['Eldrazi'],
#    'supertypes': ['Legendary'],
#    'text': 'When you cast this spell, destroy target permanent.\nIndestructible\nAnnihilator 4 (Whenever this creature attacks, defending player sacrifices four permanents.)\nWhen Ulamog, the Infinite Gyre is put into a graveyard from anywhere, its owner shuffles their graveyard into their library.',
#    'toughness': '10',
#    'type': 'Legendary Creature — Eldrazi',
#    'types': ['Creature'],
#    'uuid': '664e694d-acf8-5937-b1ca-9ce8ce48762c',
#    'variations': ['1458a72a-e137-5813-8a82-70cb454e3ffa',
#     '1e2054ca-3739-5e40-be61-38d01bba937c',
#     '9c11a355-fd21-5a81-a8a4-0ccb2f34aabe']},
#   {'artist': 'Steven Belledin',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 3.0,
#    'edhrecRank': 1437,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': 'The fastest way across the dunes is above.',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263562',
#     'cardKingdomId': '262999',
#     'mcmId': '665700',
#     'mcmMetaId': '210302',
#     'mtgjsonV4Id': '26007729-97f3-5e07-b717-34c9db7cff79',
#     'mtgoId': '101492',
#     'multiverseId': '571337',
#     'scryfallId': 'db62ac2c-0d24-4d6f-a6ca-cca4371a3bd7',
#     'scryfallIllustrationId': '3ef04134-5c97-48d1-b6fb-13273c091ddc',
#     'scryfallOracleId': '8b972819-507a-40a9-ab1f-1a674ea56083',
#     'tcgplayerProductId': '276538'},
#    'isReprint': True,
#    'keywords': ['Outlast'],
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'explorer': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'paupercommander': 'Restricted',
#     'penny': 'Legal',
#     'pioneer': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{2}{W}',
#    'manaValue': 3.0,
#    'name': 'Abzan Falconer',
#    'number': '4',
#    'power': '2',
#    'printings': ['2X2',
#     'C16',
#     'CM2',
#     'IMA',
#     'J21',
#     'KTK',
#     'MB1',
#     'MIC',
#     'ZNC'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/d6f964c2a8fe0ba9',
#     'cardKingdomFoil': 'https://mtgjson.com/links/a807950337f36a70',
#     'cardmarket': 'https://mtgjson.com/links/3bd204c14bc86c3f',
#     'tcgplayer': 'https://mtgjson.com/links/28ba3894243d3182'},
#    'rarity': 'uncommon',
#    'rulings': [{'date': '2014-09-20',
#      'text': "The cost to activate a creature's outlast ability includes the tap symbol ({T}). A creature's outlast ability can't be activated unless that creature has been under your control continuously since the beginning of your turn."},
#     {'date': '2014-09-20',
#      'text': 'Several creatures with outlast also grant an ability to creatures you control with +1/+1 counters on them, including themselves. These counters could come from an outlast ability, but any +1/+1 counter on the creature will count.'}],
#    'setCode': '2X2',
#    'subtypes': ['Human', 'Soldier'],
#    'supertypes': [],
#    'text': 'Outlast {W} ({W}, {T}: Put a +1/+1 counter on this creature. Outlast only as a sorcery.)\nEach creature you control with a +1/+1 counter on it has flying.',
#    'toughness': '3',
#    'type': 'Creature — Human Soldier',
#    'types': ['Creature'],
#    'uuid': '18468b64-37ef-5e4d-b95a-781265b533a2'},
#   {'artist': 'Chris Rahn',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 2.0,
#    'edhrecRank': 4341,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': '"Hold the line, for family and the fallen!"',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263431',
#     'cardKingdomId': '262665',
#     'mcmId': '664020',
#     'mcmMetaId': '210203',
#     'mtgjsonV4Id': 'd4cf3452-4fc1-5b82-8748-02f665c9f3a2',
#     'mtgoId': '101494',
#     'multiverseId': '571338',
#     'scryfallId': '1778cf9a-2703-41e9-86d7-ec21af8cf61d',
#     'scryfallIllustrationId': 'c145616c-e424-458f-bfa2-6745e3fbe8e6',
#     'scryfallOracleId': '8a4028cd-6004-4fb0-a044-0bee662a78e1',
#     'tcgplayerProductId': '276359'},
#    'isReprint': True,
#    'keywords': ['Outlast'],
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'explorer': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'penny': 'Legal',
#     'pioneer': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{1}{W}',
#    'manaValue': 2.0,
#    'name': 'Ainok Bond-Kin',
#    'number': '5',
#    'power': '2',
#    'printings': ['2X2', 'IMA', 'J21', 'KTK', 'MB1', 'MIC'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/83505289976b8f71',
#     'cardKingdomFoil': 'https://mtgjson.com/links/f4ebf8d602679c70',
#     'cardmarket': 'https://mtgjson.com/links/cba4cc6f015b277d',
#     'tcgplayer': 'https://mtgjson.com/links/45938682bb650ba9'},
#    'rarity': 'common',
#    'rulings': [{'date': '2014-09-20',
#      'text': "The cost to activate a creature's outlast ability includes the tap symbol ({T}). A creature's outlast ability can't be activated unless that creature has been under your control continuously since the beginning of your turn."},
#     {'date': '2014-09-20',
#      'text': 'Several creatures with outlast also grant an ability to creatures you control with +1/+1 counters on them, including themselves. These counters could come from an outlast ability, but any +1/+1 counter on the creature will count.'}],
#    'setCode': '2X2',
#    'subtypes': ['Dog', 'Soldier'],
#    'supertypes': [],
#    'text': 'Outlast {1}{W} ({1}{W}, {T}: Put a +1/+1 counter on this creature. Outlast only as a sorcery.)\nEach creature you control with a +1/+1 counter on it has first strike.',
#    'toughness': '1',
#    'type': 'Creature — Dog Soldier',
#    'types': ['Creature'],
#    'uuid': '454b109d-f148-5f55-a5a0-7316e013e8fa'},
#   {'artist': 'Antonio José Manzanedo',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 6.0,
#    'edhrecRank': 12875,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': 'Light streaked down from the heavens, and a voice whispered in the soldier\'s ear: "You shall not fall today."',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263708',
#     'cardKingdomId': '263284',
#     'mcmId': '665701',
#     'mcmMetaId': '322355',
#     'mtgjsonV4Id': 'e93d8b63-dc90-5ac9-b4ca-42e5236a3c36',
#     'mtgoId': '101496',
#     'multiverseId': '571339',
#     'scryfallId': '393fb9f7-ec03-4831-96d4-a26c89b91830',
#     'scryfallIllustrationId': '47b2f58c-3d38-4a72-99c4-137aa8f83733',
#     'scryfallOracleId': 'e4f880f5-0639-4acb-a099-e48f5707f0db',
#     'tcgplayerProductId': '277136'},
#    'isReprint': True,
#    'keywords': ['Flying'],
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'penny': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{5}{W}',
#    'manaValue': 6.0,
#    'name': 'Anointer of Valor',
#    'number': '6',
#    'power': '3',
#    'printings': ['2X2', 'CMR', 'J21'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/42e067cff7344748',
#     'cardKingdomFoil': 'https://mtgjson.com/links/7cd52ac6a6a0936e',
#     'cardmarket': 'https://mtgjson.com/links/e96cc55921936bb4',
#     'tcgplayer': 'https://mtgjson.com/links/8fb313e09e4e09e7'},
#    'rarity': 'common',
#    'rulings': [{'date': '2020-11-10',
#      'text': 'Anointer of Valor’s triggered ability triggers when any creature attacks any player or planeswalker.'},
#     {'date': '2020-11-10',
#      'text': 'If you choose to pay {3}, a second triggered ability triggers. Players may respond to that reflexive triggered ability before the +1/+1 counter is put on the creature.'},
#     {'date': '2020-11-10',
#      'text': 'You can’t pay {3} more than once to put more than one +1/+1 counter on the attacking creature.'}],
#    'setCode': '2X2',
#    'subtypes': ['Angel'],
#    'supertypes': [],
#    'text': 'Flying\nWhenever a creature attacks, you may pay {3}. When you do, put a +1/+1 counter on that creature.',
#    'toughness': '5',
#    'type': 'Creature — Angel',
#    'types': ['Creature'],
#    'uuid': 'ab1619d5-df3c-5434-b900-36561e62468f'},
#   {'artist': 'Scott Murphy',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 2.0,
#    'edhrecRank': 11780,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': '"Welcome to the Legion. You saved a district—now let\'s go save the world."',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263709',
#     'cardKingdomId': '263285',
#     'mcmId': '665702',
#     'mcmMetaId': '269802',
#     'mtgjsonV4Id': '9fdbf043-c425-53d0-b133-968ec8dc2117',
#     'mtgoId': '101498',
#     'multiverseId': '571340',
#     'scryfallId': '4e4e3a08-05a6-4730-8b4a-a8cb440dc299',
#     'scryfallIllustrationId': '08767d72-af36-48b9-9db0-59c8fbec56a2',
#     'scryfallOracleId': '303d74d0-84db-4694-bb1a-470cf470bc4f',
#     'tcgplayerProductId': '277141'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'explorer': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'penny': 'Legal',
#     'pioneer': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{1}{W}',
#    'manaValue': 2.0,
#    'name': 'Battlefield Promotion',
#    'number': '7',
#    'printings': ['2X2', 'JMP', 'WAR'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/48bc2646285ccc8f',
#     'cardKingdomFoil': 'https://mtgjson.com/links/d802eff062ac4407',
#     'cardmarket': 'https://mtgjson.com/links/c61602ed012ebe44',
#     'tcgplayer': 'https://mtgjson.com/links/edc350a596b3728d'},
#    'rarity': 'common',
#    'rulings': [{'date': '2019-05-03',
#      'text': 'If the target creature is an illegal target by the time Battlefield Promotion tries to resolve, the spell doesn’t resolve. You don’t gain 2 life.'}],
#    'setCode': '2X2',
#    'subtypes': [],
#    'supertypes': [],
#    'text': 'Put a +1/+1 counter on target creature. That creature gains first strike until end of turn. You gain 2 life.',
#    'type': 'Instant',
#    'types': ['Instant'],
#    'uuid': 'ab9fb17d-4491-50bc-adac-c230a3d6d262'},
#   {'artist': 'Victor Adame Minguez',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 5.0,
#    'edhrecRank': 1402,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': 'The angels appreciated the offer but politely declined to eat any birdseed.',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263487',
#     'cardKingdomId': '262820',
#     'mcmId': '664238',
#     'mcmMetaId': '265395',
#     'mtgjsonV4Id': 'd0789213-319d-5c04-bd0a-07fba93847ed',
#     'mtgoId': '101500',
#     'multiverseId': '571341',
#     'scryfallId': '3a73bd5a-eb22-41dc-84ff-93d23d84afae',
#     'scryfallIllustrationId': '46de50bb-1190-48c7-a2fe-c62ac830425e',
#     'scryfallOracleId': '5917216f-5b42-41fa-8976-401bdbeb782e',
#     'tcgplayerProductId': '276384'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'explorer': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pioneer': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{3}{W}{W}',
#    'manaValue': 5.0,
#    'name': 'Divine Visitation',
#    'number': '8',
#    'printings': ['2X2', 'GRN', 'PGRN'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/bd18fea566df6739',
#     'cardKingdomFoil': 'https://mtgjson.com/links/123c0a1b35508089',
#     'cardmarket': 'https://mtgjson.com/links/fa7412698b29eef9',
#     'tcgplayer': 'https://mtgjson.com/links/dc7d13534a59d646'},
#    'rarity': 'mythic',
#    'rulings': [{'date': '2018-10-05',
#      'text': 'The token’s characteristics are entirely replaced by a 4/4 white Angel creature token with flying and vigilance. It doesn’t have any abilities the token would have been created with. Anything else specified in the effect creating the token (such as tapped, attacking, “That token gains haste,” or “Exile that token at end of combat”) still applies.'},
#     {'date': '2018-10-05',
#      'text': "If you create a noncreature token that will be a creature as it enters the battlefield, perhaps because of an effect such as that of March of the Machines, Divine Visitation’s effect doesn’t apply to that token’s creation. (This is because Divine Visitation’s effect modifies how the tokens are created, and March of the Machines’s effect doesn't apply until you consider how the tokens are entering the battlefield.)"},
#     {'date': '2018-10-05',
#      'text': 'If an effect changes under whose control a token would be created, that effect applies before Divine Visitation’s effect applies. If an effect changes under whose control a token would enter the battlefield, that effect applies after Divine Visitation’s effect is able to be applied.'}],
#    'securityStamp': 'oval',
#    'setCode': '2X2',
#    'subtypes': [],
#    'supertypes': [],
#    'text': 'If one or more creature tokens would be created under your control, that many 4/4 white Angel creature tokens with flying and vigilance are created instead.',
#    'type': 'Enchantment',
#    'types': ['Enchantment'],
#    'uuid': '045cb387-99c2-5790-9a7a-b8a01736babc',
#    'variations': ['11f9b6b3-d54f-5b63-8b3b-eb0bae59608d']},
#   {'artist': 'Lars Grant-West',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 1.0,
#    'edhrecRank': 3239,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': "He vowed he would never rest until he reached his destination. He doesn't know how right he was.",
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263432',
#     'cardKingdomId': '262666',
#     'mcmId': '664021',
#     'mcmMetaId': '204055',
#     'mtgjsonV4Id': 'd07980ef-9fa6-58f6-83cc-ce96d8dd2801',
#     'mtgoId': '101502',
#     'multiverseId': '571342',
#     'scryfallId': '5642cdda-789f-4125-a9ff-7c445bb51950',
#     'scryfallIllustrationId': '29d8819e-ae8a-451c-b59e-b062993d9535',
#     'scryfallOracleId': 'a30907c0-fbde-4fd3-a8c7-f304305fcea7',
#     'tcgplayerProductId': '276249'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'penny': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{W}',
#    'manaValue': 1.0,
#    'name': 'Doomed Traveler',
#    'number': '9',
#    'power': '1',
#    'printings': ['2X2',
#     'BBD',
#     'CMR',
#     'CN2',
#     'CNS',
#     'DDK',
#     'DDQ',
#     'E01',
#     'IMA',
#     'ISD',
#     'J21',
#     'MB1'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/34e3ae4b535b1634',
#     'cardKingdomFoil': 'https://mtgjson.com/links/0095dfcd65275ee6',
#     'cardmarket': 'https://mtgjson.com/links/7c9e53cb08939f13',
#     'tcgplayer': 'https://mtgjson.com/links/d61dd6879068a09a'},
#    'rarity': 'common',
#    'rulings': [],
#    'setCode': '2X2',
#    'subtypes': ['Human', 'Soldier'],
#    'supertypes': [],
#    'text': 'When Doomed Traveler dies, create a 1/1 white Spirit creature token with flying.',
#    'toughness': '1',
#    'type': 'Creature — Human Soldier',
#    'types': ['Creature'],
#    'uuid': '270cb060-9fcf-5a5a-b87e-6ec5a0e278b5'},
#   {'artist': 'Antonio José Manzanedo',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['G', 'W'],
#    'colors': ['W'],
#    'convertedManaCost': 4.0,
#    'edhrecRank': 2603,
#    'finishes': ['nonfoil', 'foil'],
#    'foreignData': [],
#    'frameEffects': ['legendary'],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263676',
#     'cardKingdomId': '263213',
#     'mcmId': '665703',
#     'mcmMetaId': '308554',
#     'mtgjsonV4Id': 'e4d0bfbd-2913-51db-99ae-9f3007b84a48',
#     'mtgoId': '101504',
#     'multiverseId': '571343',
#     'scryfallId': '0f594562-7e9f-47e6-a033-fb70e3cf1e10',
#     'scryfallIllustrationId': '87cb9f6a-9ea0-4f25-a0ab-fa9382e677f1',
#     'scryfallOracleId': 'b11c250c-f191-4c52-ba02-a9176f163447',
#     'tcgplayerProductId': '277143'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'normal',
#    'leadershipSkills': {'brawl': False,
#     'commander': True,
#     'oathbreaker': False},
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{2}{W}{W}',
#    'manaValue': 4.0,
#    'name': 'Emiel the Blessed',
#    'number': '10',
#    'power': '4',
#    'printings': ['2X2', 'JMP'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/529e758525f574a6',
#     'cardKingdomFoil': 'https://mtgjson.com/links/613804b4d396c7b3',
#     'cardmarket': 'https://mtgjson.com/links/60ac05cf7d0f6b41',
#     'tcgplayer': 'https://mtgjson.com/links/b7596ab0b4de0e7a'},
#    'rarity': 'mythic',
#    'rulings': [{'date': '2020-06-23',
#      'text': 'When the card returns to the battlefield, it will be a new object with no connection to the card that was exiled. Auras attached to the exiled creature will be put into their owners’ graveyards. Any Equipment will become unattached and remain on the battlefield. Any counters on the exiled creature will cease to exist.'},
#     {'date': '2020-06-23',
#      'text': 'If a token is exiled this way, it will cease to exist and won’t return to the battlefield.'},
#     {'date': '2020-06-23',
#      'text': 'Emiel’s second ability triggers whenever any creature other than itself enters the battlefield under your control, including those returned by its first ability.'},
#     {'date': '2020-06-23',
#      'text': 'You choose whether to pay for Emiel’s triggered ability while it’s resolving. If you do, no player may take other actions between the time you pay and the time the creature has one or two +1/+1 counters on it.'},
#     {'date': '2020-06-23',
#      'text': 'While resolving Emiel’s triggered ability, you can’t pay {G/W} more than once to put more counters on the creature.'},
#     {'date': '2020-06-23',
#      'text': 'If the entering creature is a Unicorn, you still have to pay {G/W} to put two +1/+1 counters on it.'}],
#    'securityStamp': 'oval',
#    'setCode': '2X2',
#    'subtypes': ['Unicorn'],
#    'supertypes': ['Legendary'],
#    'text': "{3}: Exile another target creature you control, then return it to the battlefield under its owner's control.\nWhenever another creature enters the battlefield under your control, you may pay {G/W}. If you do, put a +1/+1 counter on it. If it's a Unicorn, put two +1/+1 counters on it instead. ({G/W} can be paid with either {G} or {W}.)",
#    'toughness': '4',
#    'type': 'Legendary Creature — Unicorn',
#    'types': ['Creature'],
#    'uuid': 'eefc87b8-59ea-53e9-9a44-7ba5e4fefd91',
#    'variations': ['60b71ed3-0e96-57c4-a06a-d816e986cb83',
#     'f3fe7174-21b1-54e4-ba62-7315e7184662']},
#   {'artist': 'Jeremy Enecio',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 3.0,
#    'edhrecRank': 1732,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': 'Its wings disturb more than air.',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263635',
#     'cardKingdomId': '263149',
#     'mcmId': '665137',
#     'mcmMetaId': '9857',
#     'mtgjsonV4Id': 'fdf16457-61d9-5d4c-9bb7-f906aadd1b1a',
#     'mtgoId': '101506',
#     'multiverseId': '571344',
#     'scryfallId': 'f6cccf30-2025-49bb-9b1e-240bbef03f27',
#     'scryfallIllustrationId': 'd05cfe62-b9ad-445f-8063-ef3dc34724ab',
#     'scryfallOracleId': 'b23a3d30-6b8e-4aad-890f-db0c3af43ace',
#     'tcgplayerProductId': '276909'},
#    'isReprint': True,
#    'keywords': ['Flying'],
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'paupercommander': 'Restricted',
#     'vintage': 'Legal'},
#    'manaCost': '{1}{W}{W}',
#    'manaValue': 3.0,
#    'name': 'Flickerwisp',
#    'number': '11',
#    'power': '3',
#    'printings': ['2X2',
#     '2XM',
#     'C13',
#     'C14',
#     'CMA',
#     'CMR',
#     'E01',
#     'EVE',
#     'KHC',
#     'MM3',
#     'MMA',
#     'TD0',
#     'TSR'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/1ac38080e99e013c',
#     'cardKingdomFoil': 'https://mtgjson.com/links/3a85901c9d2b2873',
#     'cardmarket': 'https://mtgjson.com/links/e7ec8b1ff1ecc149',
#     'tcgplayer': 'https://mtgjson.com/links/a689aace70664828'},
#    'rarity': 'uncommon',
#    'rulings': [{'date': '2021-03-19',
#      'text': 'The exiled card will return to the battlefield at the beginning of the end step even if Flickerwisp is no longer on the battlefield.'},
#     {'date': '2021-03-19',
#      'text': "If the permanent that returns to the battlefield has any abilities that trigger at the beginning of the end step, those abilities won't trigger that turn."},
#     {'date': '2021-03-19',
#      'text': "Auras attached to the exiled permanent will be put into their owners' graveyards. Equipment attached to the exiled permanent will become unattached and remain on the battlefield. Any counters on the exiled permanent will cease to exist. Once the exiled permanent returns, it's considered a new object with no relation to the object that it was."},
#     {'date': '2021-03-19',
#      'text': "If a token is exiled this way, it will cease to exist and won't return to the battlefield."}],
#    'setCode': '2X2',
#    'subtypes': ['Elemental'],
#    'supertypes': [],
#    'text': "Flying\nWhen Flickerwisp enters the battlefield, exile another target permanent. Return that card to the battlefield under its owner's control at the beginning of the next end step.",
#    'toughness': '1',
#    'type': 'Creature — Elemental',
#    'types': ['Creature'],
#    'uuid': '106f7578-028f-5c49-bef6-03f9d65a77bd',
#    'variations': ['e129055d-563d-55e5-a33b-9f683dc37d84']},
#   {'artist': 'Mark Winters',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 1.0,
#    'edhrecRank': 2227,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': 'Honor the gods of Theros, and they will return the favor.',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263433',
#     'cardKingdomId': '262667',
#     'mcmId': '664022',
#     'mcmMetaId': '208626',
#     'mtgjsonV4Id': 'aa131a5f-ecb9-5ef4-ac94-81b7ecd46d71',
#     'mtgoId': '101508',
#     'multiverseId': '571345',
#     'scryfallId': 'e8181eee-c03b-40db-aea1-24a4b34a4785',
#     'scryfallIllustrationId': '5ee4fe78-89f0-4448-b281-22f780bdb186',
#     'scryfallOracleId': '48e603a2-b965-4fbc-ad57-4388bce5ac8b',
#     'tcgplayerProductId': '276250'},
#    'isReprint': True,
#    'keywords': ['Scry'],
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'explorer': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'penny': 'Legal',
#     'pioneer': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{W}',
#    'manaValue': 1.0,
#    'name': 'Gods Willing',
#    'number': '12',
#    'printings': ['2X2', 'A25', 'CN2', 'M20', 'MB1', 'STA', 'THS', 'UMA'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/18b4a0dfe90b14b1',
#     'cardKingdomFoil': 'https://mtgjson.com/links/138944bf20d72857',
#     'cardmarket': 'https://mtgjson.com/links/0cb7ada39359f43a',
#     'tcgplayer': 'https://mtgjson.com/links/33662c936f660115'},
#    'rarity': 'common',
#    'rulings': [{'date': '2013-09-15',
#      'text': 'You choose how to order cards returned to your library after scrying no matter where you put them.'},
#     {'date': '2013-09-15',
#      'text': 'You choose the color as Gods Willing resolves. Once the color is chosen, it’s too late for players to respond.'},
#     {'date': '2013-09-15',
#      'text': 'Scry appears on some spells and abilities with one or more targets. If all of the spell or ability’s targets are illegal when it tries to resolve, it won’t resolve and none of its effects will happen. You won’t scry.'},
#     {'date': '2013-09-15',
#      'text': 'You perform the actions stated on a card in sequence. For some spells and abilities, that means you’ll scry last. For others, that means you’ll scry and then perform other actions.'},
#     {'date': '2013-09-15',
#      'text': 'When you scry, you may put all the cards you look at back on top of your library, you may put all of those cards on the bottom of your library, or you may put some of those cards on top and the rest of them on the bottom.'},
#     {'date': '2019-07-12',
#      'text': 'You can’t choose “artifact” or “colorless” as Gods Willing asks you to choose a color because those are not colors.'},
#     {'date': '2019-07-12',
#      'text': 'If the target creature is an illegal target by the time Gods Willing tries to resolve, the spell doesn’t resolve. You won’t scry 1. If the target creature becomes an illegal target while Gods Willing is resolving (most likely because you gave it protection from white), you do scry 1.'}],
#    'setCode': '2X2',
#    'subtypes': [],
#    'supertypes': [],
#    'text': "Target creature you control gains protection from the color of your choice until end of turn. (It can't be blocked, targeted, dealt damage, enchanted, or equipped by anything of that color.)\nScry 1.",
#    'type': 'Instant',
#    'types': ['Instant'],
#    'uuid': 'c98f1fae-d2bd-5f29-87a3-30bc0035f4ed'},
#   {'artist': 'Howard Lyon',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 1.0,
#    'edhrecRank': 1938,
#    'finishes': ['nonfoil', 'foil'],
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263710',
#     'cardKingdomId': '263286',
#     'mcmId': '665704',
#     'mcmMetaId': '11116',
#     'mtgjsonV4Id': '8796c25b-4df1-5be0-9263-5dbc6aa820fb',
#     'mtgoId': '101510',
#     'multiverseId': '571346',
#     'scryfallId': 'f6cc0f1f-191a-4141-965f-8d159bf54732',
#     'scryfallIllustrationId': 'b32630a9-3f92-4759-b529-53d6214c1c15',
#     'scryfallOracleId': '354affb3-1be7-4a9e-91da-2989eb54f62d',
#     'tcgplayerProductId': '277144'},
#    'isReprint': True,
#    'keywords': ['Enchant', 'Totem armor'],
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{W}',
#    'manaValue': 1.0,
#    'name': 'Hyena Umbra',
#    'number': '13',
#    'printings': ['2X2', 'MB1', 'PC2', 'PCA', 'ROE', 'UMA'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/3caa330f5a3fecf7',
#     'cardKingdomFoil': 'https://mtgjson.com/links/62767f36ec459dd4',
#     'cardmarket': 'https://mtgjson.com/links/7b2945ba6ca72192',
#     'tcgplayer': 'https://mtgjson.com/links/fa3778e090f870eb'},
#    'rarity': 'common',
#    'rulings': [{'date': '2010-06-15',
#      'text': 'If a creature enchanted with an Aura that has totem armor would be destroyed by multiple state-based actions at the same time the totem armor’s effect will replace all of them and save the creature.'},
#     {'date': '2010-06-15',
#      'text': 'If a spell or ability (such as Planar Cleansing) would destroy both an Aura with totem armor and the permanent it’s enchanting at the same time, totem armor’s effect will save the enchanted permanent from being destroyed. Instead, the spell or ability will destroy the Aura in two different ways at the same time, but the result is the same as destroying it once.'},
#     {'date': '2010-06-15',
#      'text': 'Totem armor’s effect is mandatory. If the enchanted permanent would be destroyed, you must remove all damage from it and destroy the Aura that has totem armor instead.'},
#     {'date': '2010-06-15',
#      'text': 'Say you control a permanent enchanted with an Aura that has totem armor, and the enchanted permanent has gained a regeneration shield. The next time it would be destroyed, you choose whether to apply the regeneration effect or the totem armor effect. The other effect is unused and remains, in case the permanent would be destroyed again.'},
#     {'date': '2010-06-15',
#      'text': 'If a spell or ability says that it would “destroy” a permanent enchanted with an Aura that has totem armor, that spell or ability causes the Aura to be destroyed instead. (This matters for cards such as Karmic Justice.) Totem armor doesn’t destroy the Aura; rather, it changes the effects of the spell or ability. On the other hand, if a spell or ability deals lethal damage to a creature enchanted with an Aura that has totem armor, the game rules regarding lethal damage cause the Aura to be destroyed, not that spell or ability.'},
#     {'date': '2010-06-15',
#      'text': 'Totem armor’s effect is not regeneration. Specifically, if totem armor’s effect is applied, the enchanted permanent does not become tapped and is not removed from combat as a result. Effects that say the enchanted permanent can’t be regenerated (as Vendetta does) won’t prevent totem armor’s effect from being applied.'},
#     {'date': '2010-06-15',
#      'text': 'Totem armor’s effect is applied no matter why the enchanted permanent would be destroyed: because it’s been dealt lethal damage, or because it’s being affected by an effect that says to “destroy” it (such as Doom Blade). In either case, all damage is removed from the permanent and the Aura is destroyed instead.'},
#     {'date': '2010-06-15',
#      'text': 'If a permanent you control is enchanted with multiple Auras that have totem armor, and the enchanted permanent would be destroyed, one of those Auras is destroyed instead — but only one of them. You choose which one because you control the enchanted permanent.'},
#     {'date': '2013-07-01',
#      'text': 'Totem armor has no effect if the enchanted permanent is put into a graveyard for any other reason, such as if it’s sacrificed, if it’s legendary and another legendary permanent with the same name is controlled by the same player, or if its toughness is 0 or less.'},
#     {'date': '2013-07-01',
#      'text': 'If a creature enchanted with an Aura that has totem armor has indestructible, lethal damage and effects that try to destroy it simply have no effect. Totem armor won’t do anything because it won’t have to.'},
#     {'date': '2013-07-01',
#      'text': 'Say you control a permanent enchanted with an Aura that has totem armor, and that Aura has gained a regeneration shield. The next time the enchanted permanent would be destroyed, the Aura would be destroyed instead — but it regenerates, so nothing is destroyed at all. Alternately, if that Aura somehow gains indestructible, the enchanted permanent is effectively indestructible as well.'}],
#    'setCode': '2X2',
#    'subtypes': ['Aura'],
#    'supertypes': [],
#    'text': 'Enchant creature\nEnchanted creature gets +1/+1 and has first strike.\nTotem armor (If enchanted creature would be destroyed, instead remove all damage from it and destroy this Aura.)',
#    'type': 'Enchantment — Aura',
#    'types': ['Enchantment'],
#    'uuid': '96dd18dd-d401-53eb-8c56-9de750ce403c'},
#   {'artist': 'Matt Stewart',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 5.0,
#    'edhrecRank': 14372,
#    'finishes': ['nonfoil', 'foil'],
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263711',
#     'cardKingdomId': '263287',
#     'mcmId': '665705',
#     'mcmMetaId': '206523',
#     'mtgjsonV4Id': 'ef941cab-eeab-5b03-afed-827c819f3126',
#     'mtgoId': '101512',
#     'multiverseId': '571347',
#     'scryfallId': 'c0f20ca6-1a92-4be5-a84a-e7f8f0b7f648',
#     'scryfallIllustrationId': 'cd749e21-1ab8-41c6-9e37-91a1fb71b6bf',
#     'scryfallOracleId': '9ba6cec6-97bf-4a83-9ffa-77e187d0945b',
#     'tcgplayerProductId': '277146'},
#    'isReprint': True,
#    'keywords': ['Enchant'],
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'explorer': 'Legal',
#     'gladiator': 'Legal',
#     'historic': 'Legal',
#     'historicbrawl': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'penny': 'Legal',
#     'pioneer': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{4}{W}',
#    'manaValue': 5.0,
#    'name': 'Knightly Valor',
#    'number': '14',
#    'printings': ['2X2', 'JMP', 'M19', 'ORI', 'RTR'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/f8bc05fc8a6ba4ac',
#     'cardKingdomFoil': 'https://mtgjson.com/links/27b5e6a070b09d12',
#     'cardmarket': 'https://mtgjson.com/links/e3d1e1587c0f9dab',
#     'tcgplayer': 'https://mtgjson.com/links/c93697f6bd24e3ef'},
#    'rarity': 'common',
#    'rulings': [{'date': '2018-07-13',
#      'text': 'You need a creature for Knightly Valor to target as you cast it. There’s no way to have it enter the battlefield attached to the Knight token it’ll create.'},
#     {'date': '2018-07-13',
#      'text': 'If the creature this Aura would enchant is an illegal target by the time Knightly Valor tries to resolve, the Aura spell doesn’t resolve. It won’t enter the battlefield, so its ability won’t trigger.'}],
#    'setCode': '2X2',
#    'subtypes': ['Aura'],
#    'supertypes': [],
#    'text': "Enchant creature\nWhen Knightly Valor enters the battlefield, create a 2/2 white Knight creature token with vigilance. (Attacking doesn't cause it to tap.)\nEnchanted creature gets +2/+2 and has vigilance.",
#    'type': 'Enchantment — Aura',
#    'types': ['Enchantment'],
#    'uuid': '4ffc473c-aaa2-5352-8050-1b833b142e84'},
#   {'artist': 'Christina Davis',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 2.0,
#    'edhrecRank': 19239,
#    'finishes': ['nonfoil', 'foil'],
#    'flavorText': 'He gasped in wonder even as his body crumbled away.',
#    'foreignData': [],
#    'frameVersion': '2015',
#    'hasFoil': True,
#    'hasNonFoil': True,
#    'identifiers': {'cardKingdomFoilId': '263712',
#     'cardKingdomId': '263288',
#     'mcmId': '665706',
#     'mcmMetaId': '3199',
#     'mtgjsonV4Id': '3db92070-63bd-5a72-8c0c-0bb0043ed89f',
#     'mtgoId': '101514',
#     'multiverseId': '571348',
#     'scryfallId': '12cca37a-7efd-4b01-bf96-15d0a032524d',
#     'scryfallIllustrationId': '64eab34b-2c7c-4609-afe5-b610f17f5ec0',
#     'scryfallOracleId': 'e6fb4f0d-ce49-4913-a2ef-88365e4916cf',
#     'tcgplayerProductId': '277147'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'normal',
#    'legalities': {'commander': 'Legal',
#     'duel': 'Legal',
#     'legacy': 'Legal',
#     'modern': 'Legal',
#     'pauper': 'Legal',
#     'paupercommander': 'Legal',
#     'penny': 'Legal',
#     'pioneer': 'Legal',
#     'premodern': 'Legal',
#     'vintage': 'Legal'},
#    'manaCost': '{1}{W}',
#    'manaValue': 2.0,
#    'name': 'Last Breath',
#    'number': '15',
#    'printings': ['2X2', 'MMQ', 'SHM', 'THS'],
#    'purchaseUrls': {'cardKingdom': 'https://mtgjson.com/links/1d4842d08ee49809',
#     'cardKingdomFoil': 'https://mtgjson.com/links/8aba0220d6f11cf1',
#     'cardmarket': 'https://mtgjson.com/links/6d60383c572d1497',
#     'tcgplayer': 'https://mtgjson.com/links/ac8210df118dee73'},
#    'rarity': 'common',
#    'rulings': [{'date': '2013-09-15',
#      'text': 'If the creature is an illegal target when Last Breath tries to resolve, it won’t resolve and none of its effects will happen. Its controller won’t gain 4 life.'}],
#    'setCode': '2X2',
#    'subtypes': [],
#    'supertypes': [],
#    'text': 'Exile target creature with power 2 or less. Its controller gains 4 life.',
#    'type': 'Instant',
#    'types': ['Instant'],
#    'uuid': '848c6273-60e1-5c8f-af31-8ca166021e96'},
#   {'artist': 'Shelly Wan',
#    'availability': ['mtgo', 'paper'],
#    'boosterTypes': ['draft'],
#    'borderColor': 'black',
#    'colorIdentity': ['W'],
#    'colors': ['W'],
#    'convertedManaCost': 2.0,
#    'edhrecRank': 3307,
#    'finishes': ['nonfoil', 'foil'],
# ...
#    'types': ['Token', 'Creature'],
#    'uuid': '18eef80e-48c6-500e-98cf-3ed4c3601b55'},
#   {'artist': 'Jesper Ejsing',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': ['G'],
#    'colors': ['G'],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': '51dd51e6-e4b3-5a91-8533-c278920e0a26',
#     'scryfallId': '8a911fad-7af3-4bc4-bafc-cac2d5f18f22',
#     'scryfallIllustrationId': '8225805c-226e-40b1-9758-11efa105bd74',
#     'scryfallOracleId': 'e4a19155-6689-43de-8175-f28dd2cf0a9a'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Boar',
#    'number': '15',
#    'power': '3',
#    'reverseRelated': ['Brindle Shoat'],
#    'setCode': 'T2X2',
#    'subtypes': ['Boar'],
#    'supertypes': [],
#    'toughness': '3',
#    'type': 'Token Creature — Boar',
#    'types': ['Token', 'Creature'],
#    'uuid': 'c8599875-0389-5953-be39-61a5a7b5bb6a'},
#   {'artist': 'Christopher Burdett',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': ['G'],
#    'colors': ['G'],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': 'c053b0a1-2380-558a-aa53-2cf270abf9b3',
#     'scryfallId': '7b545a43-8837-49a1-83d8-7c548d5237d2',
#     'scryfallIllustrationId': '9cf87a3c-45cb-49f0-b7fe-6d7387ac0b9b',
#     'scryfallOracleId': '3d4ebac1-6151-4c6f-93ae-7110e54af786'},
#    'isReprint': True,
#    'keywords': ['Defender'],
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Egg',
#    'number': '16',
#    'power': '0',
#    'reverseRelated': ['Atla Palani, Nest Tender'],
#    'setCode': 'T2X2',
#    'subtypes': ['Egg'],
#    'supertypes': [],
#    'text': 'Defender',
#    'toughness': '1',
#    'type': 'Token Creature — Egg',
#    'types': ['Token', 'Creature'],
#    'uuid': '9db7edf6-2139-5df7-8e94-5906ee38136d'},
#   {'artist': 'Brad Rigney',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': ['G'],
#    'colors': ['G'],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': '3babf062-ddd6-50b3-a90f-065032873f2d',
#     'scryfallId': 'b2c9bcf4-4e8c-467c-8c72-4a9cd0556e93',
#     'scryfallIllustrationId': '54430daa-acec-42fc-9330-ef8c4c015569',
#     'scryfallOracleId': '2b7dba01-b08c-4218-9fc1-da55559d9155'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Saproling',
#    'number': '17',
#    'power': '1',
#    'reverseRelated': ['Aether Mutation',
#     'Artifact Mutation',
#     'Aura Mutation',
#     'Bramble Elemental',
#     'Deathbloom Thallid',
#     'Deathspore Thallid',
#     'Dreampod Druid',
#     'Druidic Satchel',
#     'Elvish Farmer',
#     'Fists of Ironwood',
#     'Flash Foliage',
#     'Fungal Infection',
#     'Fungal Plots',
#     'Fungal Rebirth',
#     'Fungal Sprouting',
#     'Ghave, Guru of Spores',
#     'Golgari Germination',
#     'Greener Pastures',
#     'Jade Mage',
#     'Jund Battlemage',
#     'Korozda Guildmage',
#     'Last Stand',
#     'Morbid Bloom',
#     'Mycologist',
#     'Mycoloth',
#     'Necrogenesis',
#     'Nemata, Grove Guardian',
#     'Night Soil',
#     'Overgrown Armasaur',
#     'Pallid Mycoderm',
#     'Pollenbright Wings',
#     'Psychotrope Thallid',
#     "Rith's Charm",
#     'Rith, the Awakener',
#     'Saproling Cluster',
#     'Saproling Infestation',
#     'Saproling Migration',
#     'Saproling Symbiosis',
#     'Sarpadian Empires, Vol. VII',
#     'Savage Thallid',
#     'Scatter the Seeds',
#     'Seed Spark',
#     'Selesnya Evangel',
#     'Selesnya Guildmage',
#     'Slimefoot, the Stowaway',
#     'Spontaneous Generation',
#     'Spore Burst',
#     'Sporemound',
#     'Sporesower Thallid',
#     'Spore Swarm',
#     'Sporeweb Weaver',
#     'Sporogenesis',
#     'Sporoloth Ancient',
#     'Sprout',
#     'Sprouting Thrinax',
#     'Sprout Swarm',
#     'Supply // Demand',
#     'Tana, the Bloodsower',
#     'Tendershoot Dryad',
#     'Thallid',
#     'Thallid Devourer',
#     'Thallid Germinator',
#     'Thallid Shell-Dweller',
#     'Thelonite Hermit',
#     'Tukatongue Thallid',
#     'Ulasht, the Hate Seed',
#     'Undercellar Myconid',
#     'Utopia Mycon',
#     'Verdant Embrace',
#     'Verdant Force',
#     'Verdeloth the Ancient',
#     'Vitaspore Thallid',
#     'Vitu-Ghazi, the City-Tree',
#     'Yavimaya Sapherd',
#     'Grand Ossuary',
#     'Saproling Cluster',
#     'Verdant Force'],
#    'setCode': 'T2X2',
#    'subtypes': ['Saproling'],
#    'supertypes': [],
#    'toughness': '1',
#    'type': 'Token Creature — Saproling',
#    'types': ['Token', 'Creature'],
#    'uuid': 'b04a8173-24b6-577f-a150-cd7e51791c04'},
#   {'artist': 'Slawomir Maniak',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': ['G'],
#    'colors': ['G'],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': '735d8bf3-2272-559f-b88c-67ada78aa55d',
#     'scryfallId': 'f74900ca-7f0d-460c-86b0-b515c8b44e67',
#     'scryfallIllustrationId': '2dabea78-8f20-4076-ab75-32393ca41301',
#     'scryfallOracleId': 'bd386399-69f0-4653-96a1-fd05b8fd148c'},
#    'isReprint': True,
#    'keywords': ['Reach'],
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Spider',
#    'number': '18',
#    'power': '1',
#    'reverseRelated': ['Arachnogenesis',
#     'Arasta of the Endless Web',
#     'Brood Weaver',
#     'Curse of Clinging Webs',
#     "Gloomwidow's Feast",
#     'Ishkanah, Grafwidow',
#     'Rotwidow Pack',
#     'Spider Spawning',
#     'Twin-Silk Spider'],
#    'setCode': 'T2X2',
#    'subtypes': ['Spider'],
#    'supertypes': [],
#    'text': 'Reach',
#    'toughness': '2',
#    'type': 'Token Creature — Spider',
#    'types': ['Token', 'Creature'],
#    'uuid': '23cf1fd4-4cb8-52d1-89ca-401b60ff3ec9'},
#   {'artist': 'Cynthia Sheppard',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': ['B', 'G', 'R'],
#    'colors': ['B', 'G', 'R'],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': '104451c5-539b-597f-a07d-ac1b1e06147e',
#     'scryfallId': 'b1e883aa-5f73-4c45-9253-1350c24222e4',
#     'scryfallIllustrationId': '6fc2b4bb-aff7-4c46-8ee5-661a71df0dea',
#     'scryfallOracleId': 'afdf7400-0723-4f0d-b3d8-46ad3a698908'},
#    'isReprint': True,
#    'keywords': ['Flying'],
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Cat Dragon',
#    'number': '19',
#    'power': '3',
#    'reverseRelated': ['Wasitora, Nekoru Queen'],
#    'setCode': 'T2X2',
#    'subtypes': ['Cat', 'Dragon'],
#    'supertypes': [],
#    'text': 'Flying',
#    'toughness': '3',
#    'type': 'Token Creature — Cat Dragon',
#    'types': ['Token', 'Creature'],
#    'uuid': '77468071-de65-572f-80bc-88e11a77392f'},
#   {'artist': 'Chuck Lukacs',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': ['B', 'G'],
#    'colors': ['B', 'G'],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': 'f3447993-1b05-5134-a203-8a87dc6edfcf',
#     'scryfallId': 'd8b71ab8-7f94-4cd9-9a15-0c2291e17b47',
#     'scryfallIllustrationId': '378a91e5-1f4c-4b4a-9a65-7757e2e7a34d',
#     'scryfallOracleId': '318d6000-b6e0-4ef0-ad58-d470f4a271e6'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Worm',
#    'number': '20',
#    'power': '1',
#    'reverseRelated': ['Creakwood Liege', 'Worm Harvest'],
#    'setCode': 'T2X2',
#    'subtypes': ['Worm'],
#    'supertypes': [],
#    'toughness': '1',
#    'type': 'Token Creature — Worm',
#    'types': ['Token', 'Creature'],
#    'uuid': 'd1b963a7-1ccd-5e24-91d9-fe750f54a7fd'},
#   {'artist': 'Volkan Baǵa',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': [],
#    'colors': [],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': '1f540a22-d3e8-567d-899d-9f7ea9375d03',
#     'scryfallId': '83842dfb-e5ea-41dc-91b1-b1dd53e5ecca',
#     'scryfallIllustrationId': '61a40116-ada7-4baf-820d-cceab6b5717a',
#     'scryfallOracleId': '2dc8033c-8ad9-4888-8705-efeda938ebf0'},
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Phyrexian Golem',
#    'number': '21',
#    'power': '3',
#    'reverseRelated': ['Blade Splicer',
#     'Conversion Chamber',
#     'Ich-Tekik, Salvage Splicer',
#     'Master Splicer',
#     'Maul Splicer',
#     'Phyrexian Triniform',
#     'Sensor Splicer',
#     "Splicer's Skill",
#     'Vital Splicer',
#     'Wing Splicer'],
#    'setCode': 'T2X2',
#    'subtypes': ['Phyrexian', 'Golem'],
#    'supertypes': [],
#    'toughness': '3',
#    'type': 'Token Artifact Creature — Phyrexian Golem',
#    'types': ['Token', 'Artifact', 'Creature'],
#    'uuid': '5450889c-b58f-5974-955c-b5f0d88d1338'},
#   {'artist': 'Alayna Danner',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': [],
#    'colors': [],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': 'bce29029-b230-5513-9abb-3884569c8933',
#     'scryfallId': '649d42c1-a465-435e-8b67-e901ab9ad8ab',
#     'scryfallIllustrationId': '4e3ec01f-2a14-49b5-b5d1-f5ea41fa111f',
#     'scryfallOracleId': '3c549374-6c37-42e0-8d88-a8555d46732d'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'token',
#    'name': 'Treasure',
#    'number': '22',
#    'reverseRelated': ['Academy Manufactor',
#     'Ancient Copper Dragon',
#     "An Offer You Can't Refuse",
#     'Atsushi, the Blazing Sky',
#     'Baeloth Barrityl, Entertainer',
#     'Battle Angels of Tyr',
#     'Big Score',
#     'Black Market Connections',
#     'Black Market Tycoon',
#     'Blood Money',
#     "Bootleggers' Stash",
#     'Boxing Ring',
#     "Brass's Bounty",
#     'Brazen Freebooter',
#     "Bucknard's Everfull Purse",
#     'Burakos, Party Leader',
#     'Burdened Aerialist',
#     'Buy Your Silence',
#     'Captain Lannery Storm',
#     'Contract Killing',
#     'Corsair Captain',
#     'Crack Open',
#     'Creative Outburst',
#     'Culmination of Studies',
#     'Deadeye Plunderers',
#     'Deadly Dispute',
#     'Depths of Desire',
#     'Descent into Avernus',
#     'Dire Fleet Hoarder',
#     'Dockside Extortionist',
#     "Dungeoneer's Pack",
#     'Dungeon of the Mad Mage',
#     'Elemental Masterpiece',
#     'Excavation Technique',
#     'Exhibition Magician',
#     'Fable of the Mirror-Breaker // Reflection of Kiki-Jiki',
#     'Fae Offering',
#     'Fake Your Own Death',
#     'Forging the Tyrite Sword',
#     'Forsworn Paladin',
#     'Gadrak, the Crown-Scourge',
#     'Gala Greeters',
#     'Galazeth Prismari',
#     'Ganax, Astral Hunter',
#     'Gilded Pinions',
#     'Gleaming Barrier',
#     'Glittermonger',
#     'Gluntch, the Bestower',
#     'Goldspan Dragon',
#     'Goldvein Pick',
#     'Grim Bounty',
#     'Grim Hireling',
#     'Guild Artisan',
#     'Halo Scarab',
#     'Heap Gate',
#     'Heartless Pillage',
#     'Herald of Hadar',
#     'Hoard Hauler',
#     'Hoarding Ogre',
#     'Hoard Robber',
#     'Hornswoggle',
#     'Hullbreacher',
#     'Improvised Weaponry',
#     'Impulsive Pilferer',
#     'Indulge // Excess',
#     'Ingenious Mastery',
#     'Inspired Tinkering',
#     'Instrument of the Bards',
#     'Involuntary Employment',
#     'Jan Jansen, Chaos Crafter',
#     'Jewel-Eyed Cobra',
#     'Jewel Thief',
#     'Jolene, the Plunder Queen',
#     'Kalain, Reclusive Painter',
#     'Life Insurance',
#     'Loot Dispute',
#     'Lost Mine of Phandelver',
#     'Magda, Brazen Outlaw',
#     'Magma Opus',
#     'Mahadi, Emporium Master',
#     'Malcolm, Keen-Eyed Navigator',
#     'Marching Duodrone',
#     'Mari, the Killing Quill',
#     'Marut',
#     'Master of Ceremonies',
#     'Monologue Tax',
#     'Most Wanted',
#     'Negan, the Cold-Blooded',
#     "Noble's Purse",
#     "Ognis, the Dragon's Lash",
#     'Old Gnawbone',
#     'Old Rutstein',
#     'Patron of the Arts',
#     "Pirate's Pillage",
#     "Pirate's Prize",
#     'Pitiless Plunderer',
#     'Plundering Barbarian',
#     'Prismari Command',
#     'Prized Statue',
#     'Prizefight',
#     'Professional Face-Breaker',
#     'Prosperous Innkeeper',
#     'Prosperous Partnership',
#     'Prosperous Pirates',
#     'Prosperous Thief',
#     'Prosper, Tome-Bound',
#     'Prying Blade',
#     'Ragavan, Nimble Pilferer',
#     'Rain of Riches',
#     'Rapacious Dragon',
#     'Reckless Endeavor',
#     'Reckoner Bankbuster',
#     'Revel in Riches',
#     'Riveteers Requisitioner',
#     'Rose Room Treasurer',
#     'Ruthless Knave',
#     'Ruthless Technomancer',
#     'Safana, Calimport Cutthroat',
#     'Sailor of Means',
#     'Scion of Opulence',
#     'Seize the Spoils',
#     'Seize the Spotlight',
#     'Shambling Ghast',
#     'Shiny Impetus',
#     'Skullport Merchant',
#     'Smashing Success',
#     'Smothering Tithe',
#     "Smuggler's Share",
#     'Spell Swindle',
#     'Spiked Pit Trap',
#     'Spiteful Repossession',
#     'Sticky Fingers',
#     'Stimulus Package',
#     'Storm-Kiln Artist',
#     'Storm the Vault // Vault of Catlacan',
#     'Strike It Rich',
#     'Sudden Breakthrough',
#     'Surly Badgersaur',
#     'Swashbuckler Extraordinaire',
#     'Tavern Scoundrel',
#     'Tempting Contract',
#     "Thieves' Tools",
#     'Tireless Provisioner',
#     'Tivit, Seller of Secrets',
#     'Treasure Chest',
#     'Treasure Map // Treasure Cove',
#     'Treasure Vault',
#     'Trove of Temptation',
#     'Undercity Scrounger',
#     'Unexpected Windfall',
#     'Vault Robber',
#     'Vazi, Keen Negotiator',
#     'Visions of Ruin',
#     'Vraska, Relic Seeker',
#     'Wanted Scoundrels',
#     'Widespread Thieving',
#     'Wily Goblin',
#     'Xorn',
#     'You Find a Cursed Idol',
#     'Young Red Dragon // Bathe in Gold',
#     "You've Been Caught Stealing",
#     'Zhentarim Bandit',
#     'Ziatora, the Incinerator',
#     'Goblin Shaman',
#     'Prosper, Tome-Bound'],
#    'setCode': 'T2X2',
#    'subtypes': ['Treasure'],
#    'supertypes': [],
#    'text': '{T}, Sacrifice this artifact: Add one mana of any color.',
#    'type': 'Token Artifact — Treasure',
#    'types': ['Token', 'Artifact'],
#    'uuid': 'ba3bda5a-b0c8-5931-818b-0126c810dc7c'},
#   {'artist': 'Jaime Jones',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': [],
#    'colors': [],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': 'f4a746a2-118d-5ada-821c-3e84790bd761',
#     'scryfallId': 'fb88493c-293b-4b89-8571-712dcf110df5',
#     'scryfallIllustrationId': '8f3fff3b-48d1-44a2-84c9-d58ce3f36c8e',
#     'scryfallOracleId': '78d9bb73-904b-483e-9279-5f3f43b4bdf3'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'emblem',
#    'name': 'Liliana, the Last Hope Emblem',
#    'number': '23',
#    'reverseRelated': ['Liliana, the Last Hope'],
#    'setCode': 'T2X2',
#    'subtypes': ['Liliana'],
#    'supertypes': [],
#    'text': 'At the beginning of your end step, create X 2/2 black Zombie creature tokens, where X is two plus the number of Zombies you control.',
#    'type': 'Emblem — Liliana',
#    'types': ['Emblem'],
#    'uuid': '2d0f1dda-5182-553c-97d2-57710d02a3de'},
#   {'artist': 'Chase Stone',
#    'availability': ['paper'],
#    'borderColor': 'black',
#    'colorIdentity': [],
#    'colors': [],
#    'finishes': ['nonfoil'],
#    'frameVersion': '2015',
#    'hasFoil': False,
#    'hasNonFoil': True,
#    'identifiers': {'mtgjsonV4Id': '89005846-7c57-57a2-866e-b4c93f0843f2',
#     'scryfallId': '35578c3f-e818-4887-83c4-dc3a89e28ed4',
#     'scryfallIllustrationId': '19945b02-50cc-407c-9056-b66225a09768',
#     'scryfallOracleId': 'bc4edccc-255a-4e34-8fdb-92c7c0e3723e'},
#    'isReprint': True,
#    'language': 'English',
#    'layout': 'emblem',
#    'name': 'Wrenn and Six Emblem',
#    'number': '24',
#    'reverseRelated': ['Wrenn and Six'],
#    'setCode': 'T2X2',
#    'subtypes': ['Wrenn'],
#    'supertypes': [],
#    'text': 'Instant and sorcery cards in your graveyard have retrace. (You may cast instant and sorcery cards from your graveyard by discarding a land card in addition to paying their other costs.)',
#    'type': 'Emblem — Wrenn',
#    'types': ['Emblem'],
#    'uuid': '695a65fa-4180-5482-aed8-1c9f84226998'}],
#  'totalSetSize': 579,
#  'translations': {},
#  'type': 'masters'}

# %%
df
# Out:
#                    meta                                               data
# date         2022-07-12                                                NaN
# version  5.2.0+20220712                                                NaN
# 10E                 NaN  {'baseSetSize': 383, 'block': 'Core Set', 'boo...
# 2ED                 NaN  {'baseSetSize': 302, 'block': 'Core Set', 'boo...
# 2X2                 NaN  {'baseSetSize': 577, 'cards': [{'artist': 'Mar...
# ...                 ...                                                ...
# YSNC                NaN  {'baseSetSize': 30, 'block': 'Alchemy 2022', '...
# ZEN                 NaN  {'baseSetSize': 249, 'block': 'Zendikar', 'boo...
# ZNC                 NaN  {'baseSetSize': 1, 'block': 'Commander', 'card...
# ZNE                 NaN  {'baseSetSize': 30, 'cards': [{'artist': 'Adam...
# ZNR                 NaN  {'baseSetSize': 280, 'booster': {'arena': {'bo...
#
# [629 rows x 2 columns]
